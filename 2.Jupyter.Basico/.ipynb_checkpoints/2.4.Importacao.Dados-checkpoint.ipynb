# %% [markdown]
# # Importando Dados

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Arquivos Separados por Vírgula

# %% [markdown]
# #### Arquivos CSV

# %%
medalhas = pd.read_csv('medalhas.csv')
medalhas
# Out:
#   Medalhas  Pontuação  Nº Atletas  Média de Idade  Média de Peso
# 0   Bronze        200          10              22             56
# 1    Prata        350          20              25             58
# 2     Ouro        550          30              28             61

# %% [markdown]
# #### Arquivos TSV

# %%
# A função read_table é utilizada para ler arquivos .tsv
iris = pd.read_table('iris.tsv')
iris
# Out:
#   Comprimento da sépala Largura da sépala Comprimento da pétala  \
# 0                   5,1               3,5                   1,4
# 1                   4,9               3,0                   1,4
# 2                   4,7               3,2                   1,3
# 3                   4,6               3,1                   1,5
# 4                   5,0               3,6                   1,4
#
#   Largura da pétala    Espécie
# 0               0,2  I. setosa
# 1               0,2  I. setosa
# 2               0,2  I. setosa
# 3               0,2  I. setosa
# 4               0,2  I. setosa

# %%
# De modo alternativo, pode-se utilizar a função read_csv
# e especificar o delimitardor (\t) com o parametro delimiter
iris = pd.read_csv('iris.tsv', delimiter='\t')
iris
# Out:
#   Comprimento da sépala Largura da sépala Comprimento da pétala  \
# 0                   5,1               3,5                   1,4
# 1                   4,9               3,0                   1,4
# 2                   4,7               3,2                   1,3
# 3                   4,6               3,1                   1,5
# 4                   5,0               3,6                   1,4
#
#   Largura da pétala    Espécie
# 0               0,2  I. setosa
# 1               0,2  I. setosa
# 2               0,2  I. setosa
# 3               0,2  I. setosa
# 4               0,2  I. setosa

# %% [markdown]
# ## Planilhas do Excel (xls e xlsx)

# %%
# Em arquivos excel que possuem mais de uma planilha, 
# o comando abaixo importa o conteúdo apenas da primeira

df = pd.read_excel ('dados.xlsx')
df
# Out:
#    Funcionário  Salário                                      Email  \
# 0       Maisie     3781                      eu.metus@luctusut.net
# 1       Armand     8001              ac.orci.Ut@hendreritDonec.org
# 2        Kuame     6605                             magna@enim.net
# 3        Dante     5775                          sed@sedlibero.com
# 4       Darryl    10270                        vulputate@Morbi.org
# 5        Cairo    11599   ante.lectus.convallis@fringillapurus.org
# 6        Lewis    11418                    odio.tristique@odio.net
# 7     Jennifer    10415                         blandit@tellus.com
# 8       Dustin     5573  pellentesque.massa.lobortis@nullaDonec.ca
# 9    Alexander    10098         adipiscing@Aeneangravidanunc.co.uk
# 10    McKenzie     8261                 Ut@aliquamiaculislacus.org
# 11     Charity     3787      lectus.convallis.est@Seddiamlorem.edu
# 12    Danielle     8901                        ipsum.ac@Quisque.ca
#
#    Data de Início
# 0      2021-09-17
# 1      2020-06-24
# 2      2022-03-29
# 3      2021-06-16
# 4      2020-08-06
# 5      2020-10-19
# 6      2022-03-07
# 7      2021-11-15
# 8      2020-12-08
# 9      2020-10-19
# 10     2021-07-25
# 11     2021-05-08
# 12     2020-11-11

# %%
# Para selecionar uma planilha específica do arquivo excel
# basta utilizar o parametro sheet_name e informar o nome da mesma

df = pd.read_excel ('dados.xlsx', sheet_name ='Vendas')
df
# Out:
#    Funcionário  Nº de Vendas  Valor total
# 0       Maisie            10  8366.342388
# 1       Armand             8  5678.002320
# 2        Kuame            20   454.162020
# 3        Dante            13  7777.219345
# 4       Darryl             5  8692.105987
# 5        Cairo            16  5798.637070
# 6        Lewis            30  4869.680751
# 7     Jennifer            11  5377.980157
# 8       Dustin            12  7579.886997
# 9    Alexander             8  8506.104309
# 10    McKenzie            13  6788.052475
# 11     Charity            26  4909.583989
# 12    Danielle            29    58.420463

# %% [markdown]
# ## JavaScript Object Notation (JSON)

# %%
# Para ler arquivos JSON, basta utilizar a função abaixo

tracks = pd.read_json('Michael_Jackson_tracks.json')
tracks
# Out:
#                                               tracks
# 0  {'album': {'album_type': 'album', 'artists': [...
# 1  {'album': {'album_type': 'album', 'artists': [...
# 2  {'album': {'album_type': 'album', 'artists': [...
# 3  {'album': {'album_type': 'album', 'artists': [...
# 4  {'album': {'album_type': 'album', 'artists': [...
# 5  {'album': {'album_type': 'album', 'artists': [...
# 6  {'album': {'album_type': 'album', 'artists': [...
# 7  {'album': {'album_type': 'album', 'artists': [...
# 8  {'album': {'album_type': 'album', 'artists': [...
# 9  {'album': {'album_type': 'album', 'artists': [...

# %% [markdown]
# No entanto, a saída acima parece um pouco desajeitada, certo?
#
# Isso acontece pois este é um arquivo JSON aninhado, ou seja, ele possui vários níveis de pares [chave:valor]. O primeiro nível é a chave *__tracks__*, ou seja, cada linha do dataframe retornado é um valor para 'track'. Neste caso, não é possível transformar um arquivo JSON __aninhado__ diretamente em um dataframe, pois a função __*read_json*__ faz a leitura de strings JSON mais simples.
#
# Para o nosso exemplo, a obtenção de um dataframe organizado demanda a divisão deste JSON aninhado. Para isso, a função *__json_normalize()__* é utilizada para ler a __STRING__ JSON aninhada e devolver um DataFrame.

# %%
# Primeiro Passo: ler a string JSON com a função json.loads() 
# da biblioteca JSON

with open('Michael_Jackson_tracks.json','r') as f:
    data = json.loads(f.read())

# Segundo Passo: passamos objeto JSON (data) para a função json_normalize()
# que retornará um DataFrame contendo os dados necessários.
# Para isso, é preciso informar o primeiro nível de chave (tracks)

tracks_df = pd.json_normalize(data['tracks'])

tracks_df
# Out:
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            2
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            2
#
#    duration_ms  explicit                                               href  \
# 0       293826     False  https://api.spotify.com/v1/tracks/5ChkMS8OtdzJ...
# 1       258040     False  https://api.spotify.com/v1/tracks/1OOtq8tRnDM8...
# 2       257760     False  https://api.spotify.com/v1/tracks/2bCQHF9gdG5B...
# 3       365466     False  https://api.spotify.com/v1/tracks/46eu3SBuFCXW...
# 4       220626     False  https://api.spotify.com/v1/tracks/7oOOI85fVQvV...
# 5       298120     False  https://api.spotify.com/v1/tracks/0sKlV58cODrj...
# 6       247360     False  https://api.spotify.com/v1/tracks/5lWFrW5T3Jtx...
# 7       284160     False  https://api.spotify.com/v1/tracks/3wuCCNCnBhJl...
# 8       238733     False  https://api.spotify.com/v1/tracks/5lA3pwMkBdd2...
# 9       245786     False  https://api.spotify.com/v1/tracks/6G8kHiVZ1jW7...
#
#                        id  is_local  is_playable  \
# 0  5ChkMS8OtdzJeqyybCc9R5     False         True
# 1  1OOtq8tRnDM8kG2gqUPjAj     False         True
# 2  2bCQHF9gdG5BNDVuEIEnNk     False         True
# 3  46eu3SBuFCXWsPT39Yg3tJ     False         True
# 4  7oOOI85fVQvVnK5ynNMdW7     False         True
# 5  0sKlV58cODrjxGFOyf9IXY     False         True
# 6  5lWFrW5T3JtxVCLDb7etPu     False         True
# 7  3wuCCNCnBhJlwkIJTBZFiv     False         True
# 8  5lA3pwMkBdd24StM90QrNR     False         True
# 9  6G8kHiVZ1jW7vHMPVRNZU0     False         True
#
#                                         name  popularity  ...  \
# 0                                Billie Jean          84  ...
# 1                                    Beat It          79  ...
# 2            Smooth Criminal - 2012 Remaster          77  ...
# 3             Don't Stop 'Til You Get Enough          75  ...
# 4             Rock with You - Single Version          74  ...
# 5   The Way You Make Me Feel - 2012 Remaster          73  ...
# 6                        Bad - 2012 Remaster          72  ...
# 7                   They Don't Care About Us          71  ...
# 8                P.Y.T. (Pretty Young Thing)          71  ...
# 9  Don’t Matter To Me (with Michael Jackson)          71  ...
#
#                  album.id                                       album.images  \
# 0  1C2h7mLntPSeVYciMRTF4a  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1  1C2h7mLntPSeVYciMRTF4a  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2  24TAupSNVWSAHL0R7n71vm  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3  2ZytN2cY4Zjrr9ukb2rqTP  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4  2ZytN2cY4Zjrr9ukb2rqTP  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5  24TAupSNVWSAHL0R7n71vm  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6  24TAupSNVWSAHL0R7n71vm  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7  3OBhnTLrvkoEEETjFA3Qfk  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 8  1C2h7mLntPSeVYciMRTF4a  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9  1ATL5GLyefJaxhQzSPVrLX  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                                     album.name album.release_date  \
# 0             Thriller 25 Super Deluxe Edition         1982-11-30
# 1             Thriller 25 Super Deluxe Edition         1982-11-30
# 2                         Bad 25th Anniversary         1987-08-31
# 3                                 Off the Wall         1979-08-10
# 4                                 Off the Wall         1979-08-10
# 5                         Bad 25th Anniversary         1987-08-31
# 6                         Bad 25th Anniversary         1987-08-31
# 7  HIStory - PAST, PRESENT AND FUTURE - BOOK I         1995-06-16
# 8             Thriller 25 Super Deluxe Edition         1982-11-30
# 9                                     Scorpion         2018-06-29
#
#   album.release_date_precision album.total_tracks album.type  \
# 0                          day                 30      album
# 1                          day                 30      album
# 2                          day                 24      album
# 3                          day                 10      album
# 4                          day                 10      album
# 5                          day                 24      album
# 6                          day                 24      album
# 7                          day                 30      album
# 8                          day                 30      album
# 9                          day                 25      album
#
#                               album.uri external_ids.isrc  \
# 0  spotify:album:1C2h7mLntPSeVYciMRTF4a      USSM19902991
# 1  spotify:album:1C2h7mLntPSeVYciMRTF4a      USSM19902990
# 2  spotify:album:24TAupSNVWSAHL0R7n71vm      USSM11204989
# 3  spotify:album:2ZytN2cY4Zjrr9ukb2rqTP      USSM17900816
# 4  spotify:album:2ZytN2cY4Zjrr9ukb2rqTP      USSM17900817
# 5  spotify:album:24TAupSNVWSAHL0R7n71vm      USSM11204981
# 6  spotify:album:24TAupSNVWSAHL0R7n71vm      USSM11204980
# 7  spotify:album:3OBhnTLrvkoEEETjFA3Qfk      USSM19500629
# 8  spotify:album:1C2h7mLntPSeVYciMRTF4a      USSM19902993
# 9  spotify:album:1ATL5GLyefJaxhQzSPVrLX      USCM51800208
#
#                                external_urls.spotify
# 0  https://open.spotify.com/track/5ChkMS8OtdzJeqy...
# 1  https://open.spotify.com/track/1OOtq8tRnDM8kG2...
# 2  https://open.spotify.com/track/2bCQHF9gdG5BNDV...
# 3  https://open.spotify.com/track/46eu3SBuFCXWsPT...
# 4  https://open.spotify.com/track/7oOOI85fVQvVnK5...
# 5  https://open.spotify.com/track/0sKlV58cODrjxGF...
# 6  https://open.spotify.com/track/5lWFrW5T3JtxVCL...
# 7  https://open.spotify.com/track/3wuCCNCnBhJlwkI...
# 8  https://open.spotify.com/track/5lA3pwMkBdd24St...
# 9  https://open.spotify.com/track/6G8kHiVZ1jW7vHM...
#
# [10 rows x 28 columns]

# %% [markdown]
# A coluna __*artists*__ também é composta por mais um nível do arquivo json. Para melhor visualizar esta coluna, é preciso repetir o processo acima construindo um novo dataframe.

# %% [markdown]
# ## Outros formatos
#
# Além desses formatos, é possível carregar dados de XML e de bancos de dados.

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Este notebook apresentou como importar dados de diversos formatos para o pandas.
#
# Este foi o fim desta parte do tutorial sobre Jupyter Básico. A próxima parte [3.Preparacao](../3.Preparacao/3.1.Limpeza.ipynb) tratará da preparação de dados para a ciência de dados.
